# %%
from google.colab.patches import cv2_imshow
import cv2
image=cv2.imread("/content/pencil.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=177x116 at 0x7F122428E470>

# %%
gray_image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=177x116 at 0x7F12242B1780>

# %%
invert_image=cv2.bitwise_not(gray_image)
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=177x116 at 0x7F12242B13C8>

# %%
smooth_img=cv2.GaussianBlur(invert_image,(5,5),sigmaX=0,sigmaY=0)
cv2_imshow(smooth_img)
# Out:
# <PIL.Image.Image image mode=L size=177x116 at 0x7F12242D49B0>

# %%
def dodge(x,y):
  return cv2.divide(x,255-y,scale=256)
final_image=dodge(gray_image,smooth_img)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=L size=177x116 at 0x7F1230AE1A90>
